# %%
import swasputils

# %%
s = swasputils.UnifiedSubjects().get_workflow(7534.0)

# %%
sib = s.get_siblings(22508817)

# %%
sib.df
# Out:
#             project_id  workflow_id  subject_set_id  \
# subject_id
# 22508815          6767       7534.0           30266
# 22508816          6767       7534.0           30266
# 22508817          6767       7534.0           30266
#
#                                                      metadata  \
# subject_id
# 22508815    {"!CERiT":"https://wasp.cerit-sc.cz/search?obj...
# 22508816    {"!CERiT":"https://wasp.cerit-sc.cz/search?obj...
# 22508817    {"!CERiT":"https://wasp.cerit-sc.cz/search?obj...
#
#                                                     locations  \
# subject_id
# 22508815    {"0":"https://panoptes-uploads.zooniverse.org/...
# 22508816    {"0":"https://panoptes-uploads.zooniverse.org/...
# 22508817    {"0":"https://panoptes-uploads.zooniverse.org/...
#
#             classifications_count retired_at retirement_reason  \
# subject_id
# 22508815                        2        NaN               NaN
# 22508816                        5        NaN               NaN
# 22508817                        2        NaN               NaN
#
#                          created_at               updated_at  \
# subject_id
# 22508815    2018-06-24 13:16:49 UTC  2020-11-30 18:57:49 UTC
# 22508816    2018-06-24 13:16:50 UTC  2020-11-11 11:07:10 UTC
# 22508817    2018-06-24 13:16:50 UTC  2020-11-10 18:01:27 UTC
#
#                              SWASP ID  Period Number  Classification  \
# subject_id
# 22508815    1SWASPJ085400.49-093006.3            3.0             NaN
# 22508816    1SWASPJ085400.49-093006.3            4.0             2.0
# 22508817    1SWASPJ085400.49-093006.3            5.0             3.0
#
#             Period Uncertainty  Classification Count        Period  Sigma  \
# subject_id
# 22508815                   NaN                   NaN  114775.53125   5.58
# 22508816                   0.0                   3.0   68960.86719   5.01
# 22508817                   0.0                   1.0   57480.65625   4.68
#
#             Chi Squared
# subject_id
# 22508815         115.27
# 22508816          67.56
# 22508817          99.77

# %%
sib.plot()

# %%
sib.plot(clip=True, folded=True)

# %%
sib.plot(clip=True, folded=True, hue='camera')

# %%
sib.display_lightcurves()
# Out:
# <img src="https://panoptes-uploads.zooniverse.org/subject_location/43c28e1c-165b-47d1-b5ef-8e1ee59c2d67.gif" width="500" height="500"/>
# <img src="https://panoptes-uploads.zooniverse.org/subject_location/70b68a4a-8abc-4334-9d13-31b8a7eebefc.gif" width="500" height="500"/>
# <img src="https://panoptes-uploads.zooniverse.org/subject_location/8a473ce4-698b-4962-90e7-a2ebe73e1bd9.gif" width="500" height="500"/>

# %%
c = swasputils.ZooniverseClassifications().get_subjects(sib.df.index)

# %%
c.count_annotations().plot.bar()
# Out:
# <AxesSubplot:xlabel='subject_ids'>

# %%
c.count_annotations()
# Out:
# annotation_T0  EA/EB type  EW type  Real  Rotator
# subject_ids
# 22508815                2        0     1        0
# 22508816                3        1     1        1
# 22508817                0        2     1        0
