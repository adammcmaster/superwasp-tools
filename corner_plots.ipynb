# %%
import os
import pandas
import seaborn
import swasputils

# %%
df = pandas.read_csv(
    os.path.join(swasputils.DATA_LOCATION, 'vespa-export.csv'),
)
df.head()
# Out:
#                 SuperWASP ID  Period Length           RA          Dec  \
# 0  1SWASPJ000126.73-001344.2    24007.58594  0h01m26.73s  -0d13m44.2s
# 1  1SWASPJ000236.45+002446.3    16595.36914  0h02m36.45s   0d24m46.3s
# 2  1SWASPJ000236.45+002446.3    20553.37500  0h02m36.45s   0d24m46.3s
# 3  1SWASPJ000236.45+002446.3    27404.40430  0h02m36.45s   0d24m46.3s
# 4  1SWASPJ000236.20+002516.3    27404.29492   0h02m36.2s   0d25m16.3s
#
#    Maximum magnitude  Minimum magnitude  Mean magnitude  Amplitude  \
# 0          14.023840          21.350196       14.870849   7.326356
# 1          13.998806          16.670559       14.678380   2.671753
# 2          13.998806          16.670559       14.678380   2.671753
# 3          13.998806          16.670559       14.678380   2.671753
# 4          14.079385          17.870184       14.824788   3.790799
#
#   Classification  Classification count Folding flag  Sigma  Chi squared
# ...

# %%
seaborn.pairplot(
    df,
    hue='Classification',
    corner=True,
)
# Out:
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
seaborn.pairplot(
    df,
    hue='Folding flag',
    corner=True,
)
# Out:
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\anm83\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
