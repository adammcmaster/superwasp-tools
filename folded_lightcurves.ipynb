# %%
import swasputils

# %%
sources = swasputils.UnifiedSubjects()

# %%
sources.df = sources.df[sources.df['SWASP ID'] == '1SWASPJ003232.74-245150.6']

# %%
sources.plot(hue='camera', clip=True
            )

# %%
sources.plot(folded=True, clip=True, hue='camera')
