# %%
import swasputils

# %%
sources = swasputils.AggregatedClassifications().pulsators
sources.df = sources.df[:10]
sources.df = sources.df.merge(swasputils.FoldedLightcurves().df, how='left')

# %%
sources.plot(folded=True, clip=True)

# %%
sources.plot()
